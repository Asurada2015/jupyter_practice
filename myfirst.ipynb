# %% [markdown]
# # Table of Contents
#  <p>

# %%
# %%timeit
import math
def fibo1(n):
    if n == 0:
        return 0
    elif n ==1:
        return 1
    return fibo1(n-1) + fibo1(n-2)

# %%
# %timeit fibo1(20)
# Out:
# 3.79 ms ± 47.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
import numpy as np
import math
x = np.linspace(0, 1, 300)
for w in range(2, 6, 2):
    plt.plot(x, np.sin(np.pi*x)*np.sin(2*w*np.pi*x))

# %% [markdown]
# import numpy as np
# import tensorflow as tf
